# %%
import pandas as pd
import numpy as np
import xlrd
import os
import pprint
from tkinter import filedialog as fd
os.chdir(r"C:\Users\pallist\Desktop\ΤΡΕΧΟΝΤΑ\testing folder")
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype

# %%
onomata = pd.read_excel("ΒΑΣΗ ΟΝΟΜΑΤΩΝ (ΑΡΣΕΝΙΚΑ).xlsx")
lista_onomaton = onomata.iloc[:,1]

# %%
file= fd.askopenfilename()

# %%
stoixeia = pd.read_excel(file)
stoixeia
# Out:
#           ΕΠΙΘΕΤΟ     ΟΝΟΜΑ        ΠΑΤΡΩΝΥΜΟ     ΠΟΛΗ          ΟΔΟΣ ΑΡΙΘΜΟΣ  \
# 0       ΣΑΡΑΝΤΑΡΗ  ΠΑΝΑΓΙΩΤΑ        ΠΑΝΤΕΛΗΣ     ΑΡΤΑ     ΧΑΛΚΙΑΔΕΣ     NaN
# 1        ΜΠΑΣΟΥΚΟ     ΙΩΑΝΝΗ          ΛΟΥΚΑΣ  ΧΑΛΚΙΔΑ         ΧΑΙΝΑ       1
# 2    ΧΡΥΣΤΟΠΟΥΛΟΥ    ΔΗΜΗΤΡΑ    ΚΩΝΣΤΑΝΤΙΝΟΣ    ΛΑΜΙΑ   ΠΑΛΑΙΟΛΟΓΟΥ      14
# 3       ΚΟΛΟΤΟΥΡΟ     ΑΝΔΡΕΑ        ΓΕΩΡΓΙΟΣ  ΑΙΓΑΛΕΩ         ΣΑΜΟΥ      62
# 4    ΓΕΩΡΓΟΥΛΑΚΟΥ  ΠΑΝΑΓΙΩΤΑ         ΙΩΑΝΝΗΣ   ΝΙΚΑΙΑ   ΚΑΛΛΙΠΟΛΕΩΣ      18
# ..            ...        ...             ...      ...           ...     ...
# 409          ΦΑΚΑ       ΖΗΣΗ        ΑΧΙΛΛΕΑΣ   ΛΑΡΙΣΑ  ΠΡΟΦΗΤΗ ΗΛΙΑ      12
# 410        RALUCA     MIRELA           MIHAI    ΑΘΗΝΑ       ΣΚΙΑΘΟΥ       8
# 411     ΒΑΒΑΡΟΥΤΑ  ΠΑΝΑΓΙΩΤΗ         ΑΝΔΡΕΑΣ    ΠΑΤΡΑ      ΚΟΡΙΝΘΟΥ     385
# 412       ΚΟΤΣΙΦΑ  ΠΑΝΑΓΙΩΤΗ          ΦΩΤΙΟΣ    ΑΘΗΝΑ     ΑΝΤΙΦΙΛΟΥ      19
# 413     ELSHENIKY    ELTABEI  HASAN MOHAMMED    ΑΘΗΝΑ        ΠΟΝΤΟΥ      70
#
#         ΤΚ       ΑΦΜ    ΗΜΕΡ.ΥΠΟΓΡ.ΑΙΤΗΣΗΣ  ΑΡΙΘΜΟΣ ΑΙΤΗΣΗΣ  ...  \
# 0    47100  115068290  2020-06-15 00:00:00     9.350516e+11  ...
# 1    34100   26702675  2019-05-29 00:00:00     4.435110e+10  ...
# 2    35100  149853000  2021-04-08 00:00:00     4.420468e+08  ...
# 3    12243  165327791  2020-12-18 00:00:00     1.008424e+08  ...
# 4    18454  103197323  2020-06-12 00:00:00     6.022375e+08  ...
# ..     ...        ...                  ...              ...  ...
# 409  41335  104611180  2020-04-06 00:00:00     4.405746e+11  ...
# 410  11254  175667062  2020-07-08 00:00:00     1.004628e+10  ...
# 411  26222   46005178  2020-06-04 00:00:00     3.302309e+08  ...
# 412  11528   26875931  2019-06-26 00:00:00     1.185090e+08  ...
# 413  11527  127556214  2020-03-18 00:00:00     1.006310e+10  ...
#
#      ΗΜΕΡ.ΤΕΛΙΚΟΥ ΛΟΓΙΑΡΙΑΣΜΟΥ ΠΟΣΟ ΤΕΛΙΚΟΥ ΛΟΓΑΡΙΑΣΜΟΥ  ΗΜΕΡ.ΛΟΓΑΡΙΑΣΜΟΥ  \
# 0          2022-01-01 00:00:00                   841.22        2022-09-14
# 1          2022-01-27 00:00:00                   755.07        2022-04-13
# 2          2022-01-12 00:00:00                   735.40        2022-09-14
# 3          2022-01-01 00:00:00                   762.63        2022-09-14
# 4          2022-01-14 00:00:00                   797.84        2022-09-14
# ..                         ...                      ...               ...
# 409        2020-12-10 00:00:00                   455.04        2021-04-05
# 410        2020-12-25 00:00:00                   387.11        2021-04-05
# 411        2020-12-10 00:00:00                   424.77        2021-04-05
# 412        2020-12-10 00:00:00                   476.77        2021-04-05
# 413        2020-12-25 00:00:00                   673.48        2021-04-05
#
#     ΠΟΣΟ ΟΦΕΙΛΗΣ   ΑΘΡΟΙΣΜΑ ΠΟΣΟΥ ΟΦΕΙΛΗΣ (2 ΠΑΡΟΧΕΣ) ΣΥΜΒΑΣΗ   ΠΟΛΗ 2  \
# 0          730.40                                 NaN   VOLTON     NaN
# 1          737.62                                 NaN   VOLTON     NaN
# 2          651.39                                 NaN   VOLTON     NaN
# 3          729.38                                 NaN   VOLTON     NaN
# 4          713.91                                 NaN   VOLTON     NaN
# ..            ...                                 ...      ...     ...
# 409        349.93                                 NaN   VOLTON     NaN
# 410        348.79                                 NaN   VOLTON     NaN
# 411        346.96                                 NaN   VOLTON     NaN
# 412        341.29                                 NaN   VOLTON     NaN
# 413        340.25                                 NaN   VOLTON     NaN
#
#      ΟΔΟΣ 2 ΑΡΙΘΜΟΣ 2  ΤΚ 2
# 0       NaN       NaN   NaN
# 1       NaN       NaN   NaN
# 2       NaN       NaN   NaN
# 3       NaN       NaN   NaN
# 4       NaN       NaN   NaN
# ..      ...       ...   ...
# 409     NaN       NaN   NaN
# 410     NaN       NaN   NaN
# 411     NaN       NaN   NaN
# 412     NaN       NaN   NaN
# 413     NaN       NaN   NaN
#
# [414 rows x 23 columns]

# %%
# Insert columns of raw data into a new dataframe (if there is extra informtion about the person, add those columns too)

test = pd.DataFrame()
test["Ton"] = ""
test["Surname"] = stoixeia.iloc[:,0]
test["Name"] = stoixeia.iloc[:,1]
test["Father"] = stoixeia.iloc[:,2]

if len(stoixeia.columns) > 3 and not stoixeia.iloc[:,3].str.isnumeric().all():
    test["City"] = stoixeia.iloc[:,3]
    test["Address"] = stoixeia.iloc[:,4].astype(str)
    test["Number"] = stoixeia.iloc[:,5]
    test["Number"] = test["Number"].astype(str)
    if  is_numeric_dtype(stoixeia.iloc[:,6]):
        test["TK"] = stoixeia.iloc[:,6].fillna(0).astype(int).astype(str)
    else :
        test["TK"]  = ""
    if is_numeric_dtype(stoixeia.iloc[:,7]):
        test["ΑΦΜ"] = stoixeia.iloc[:,7].fillna(0).astype(int).astype(str)
    else :
        test["ΑΦΜ"]  = ""    
    test["stoixeia"] = ""
test.columns
# Out:
# Index(['Ton', 'Surname', 'Name', 'Father', 'City', 'Address', 'Number', 'TK',
#        'ΑΦΜ', 'stoixeia'],
#       dtype='object')

# %%
# Create hashmap dictionary για τις εξαιρέσεις των άρθρων και πόλεων 


ton_list = ["ΜΙΧΑΗΛ", "ΕΜΜΑΝΟΥΗΛ", "ΣΠΥΡΙΔΩΝ", "ΑΧΙΛΛΕΥΣ", "ΟΔΥΣΣΕΥΣ"]



keys = ["ΧΑΝΙΑ", "ΦΑΡΣΑΛΑ", "ΙΩΑΝΝΙΝΑ", "ΣΕΠΟΛΙΑ", "ΤΡΙΚΑΛΑ","ΑΝΩ ΛΙΟΣΙΑ", "ΚΑΛΥΒΙΑ", "ΜΕΓΑΡΑ","ΝΈΟ ΗΡΑΚΛΕΙΟ", "ΠΑΛΑΙΟ ΦΑΛΗΡΟ", "ΝΕΑ ΙΩΝΙΑ", "ΑΓΙΟΙ ΑΝΑΡΓΥΡΟΙ", "ΑΓΙΑ ΠΑΡΑΣΚΕΥΗ"]

values = ["ΧΑΝΙΩΝ", "ΦΑΡΣΑΛΩΝ", "ΙΩΑΝΝΙΝΩΝ", "ΣΕΠΟΛΙΩΝ","ΤΡΙΚΑΛΩΝ", "ΑΝΩ ΛΙΟΣΙΩΝ", "ΚΑΛΥΒΙΩΝ", "ΜΕΓΑΡΩΝ", "ΝΕΟΥ ΗΡΑΚΛΕΙΟΥ", "ΠΑΛΑΙΟΥ ΦΑΛΗΡΟΥ", "ΝΕΑΣ ΙΩΝΙΑΣ" , "ΑΓΙΩΝ ΑΝΑΡΓΥΡΩΝ", "ΑΓΙΑΣ ΠΑΡΑΣΚΕΥΗΣ"]

city_dict = dict(zip(keys, values))

# %%
# Fix names and cities functions

def names () :
    ton_list = []
    for t in test["Name"] :
            x = str(t)
            for ton1 in ton_list :
                if x == ton1:
                    ton_list.append("Τον")            
            if x[-2:] == "ΟΣ" or x[-2:] == "ΗΣ" :
                ton_list.append("Τον")
            elif x[-1:] == "Α" or x[-1:] == "Η":
                ton_list.append("Την")
            else :
                ton_list.append("Την")    
    test["Ton"] = ton_list

    surname_list = []
    
    
    for t in test["Surname"] :
        if t[-1] == "Σ" :
            t = t[:-1]
        surname_list.append(t)        
    test["Surname"] = surname_list        

    name_list = []

    for t in test["Name"] :
        if t[-1] == "Σ" :
            t = t[:-1]
        name_list.append(t)

    test["Name"] = name_list

    father_list = []

    for t in test["Father"] :
        x = str(t)
        if x[-2:] == "ΗΣ" or x[-2:] == "ΑΣ" :
            x = x[:-1]
        elif x[-2:] == "ΟΣ":
            x = x[:-1] + "Y"
    #     print(x)
        father_list.append(x)        

    test["Father"] = father_list

# %%
def cities() :    
    
    city_list = []

    for t in test["City"] :
        x = str(t)

        for city1, city2 in city_dict.items() :
            if x == city1:
                x = city2
        
        if x[-1] == "Α" or x[-1] == "Η" :
            x = x + "Σ"
        
        elif x[-2:] == "ΑΣ" :
            x = x[:-1]    
    
        elif x[-2:] == "ΕΣ" or x[-2:] == "ΟΙ":
            x = x[:-2] + "ΩΝ"    
            
        elif x[-1] == "Ι"  :
            x = x + "ΟΥ"

        elif x[-1] == "Ο"  :
            x = x + "Υ"

        elif x[-2:] == "ΟΣ" :
            x = x[:-1] + "Y"

        city_list.append(x)

    test["City"] = city_list

# %%
test
# Out:
#      Ton       Surname       Name          Father     City       Address  \
# 0    NaN     ΣΑΡΑΝΤΑΡΗ  ΠΑΝΑΓΙΩΤΑ        ΠΑΝΤΕΛΗΣ     ΑΡΤΑ     ΧΑΛΚΙΑΔΕΣ
# 1    NaN      ΜΠΑΣΟΥΚΟ     ΙΩΑΝΝΗ          ΛΟΥΚΑΣ  ΧΑΛΚΙΔΑ         ΧΑΙΝΑ
# 2    NaN  ΧΡΥΣΤΟΠΟΥΛΟΥ    ΔΗΜΗΤΡΑ    ΚΩΝΣΤΑΝΤΙΝΟΣ    ΛΑΜΙΑ   ΠΑΛΑΙΟΛΟΓΟΥ
# 3    NaN     ΚΟΛΟΤΟΥΡΟ     ΑΝΔΡΕΑ        ΓΕΩΡΓΙΟΣ  ΑΙΓΑΛΕΩ         ΣΑΜΟΥ
# 4    NaN  ΓΕΩΡΓΟΥΛΑΚΟΥ  ΠΑΝΑΓΙΩΤΑ         ΙΩΑΝΝΗΣ   ΝΙΚΑΙΑ   ΚΑΛΛΙΠΟΛΕΩΣ
# ..   ...           ...        ...             ...      ...           ...
# 409  NaN          ΦΑΚΑ       ΖΗΣΗ        ΑΧΙΛΛΕΑΣ   ΛΑΡΙΣΑ  ΠΡΟΦΗΤΗ ΗΛΙΑ
# 410  NaN        RALUCA     MIRELA           MIHAI    ΑΘΗΝΑ       ΣΚΙΑΘΟΥ
# 411  NaN     ΒΑΒΑΡΟΥΤΑ  ΠΑΝΑΓΙΩΤΗ         ΑΝΔΡΕΑΣ    ΠΑΤΡΑ      ΚΟΡΙΝΘΟΥ
# 412  NaN       ΚΟΤΣΙΦΑ  ΠΑΝΑΓΙΩΤΗ          ΦΩΤΙΟΣ    ΑΘΗΝΑ     ΑΝΤΙΦΙΛΟΥ
# 413  NaN     ELSHENIKY    ELTABEI  HASAN MOHAMMED    ΑΘΗΝΑ        ΠΟΝΤΟΥ
#
#     Number     TK        ΑΦΜ stoixeia
# 0      nan  47100  115068290
# 1        1  34100   26702675
# 2       14  35100  149853000
# 3       62  12243  165327791
# 4       18  18454  103197323
# ..     ...    ...        ...      ...
# 409     12  41335  104611180
# 410      8  11254  175667062
# 411    385  26222   46005178
# 412     19  11528   26875931
# 413     70  11527  127556214
#
# [414 rows x 10 columns]

# %%
names()
if len(stoixeia.columns) > 4 :
    cities()
    
    test["stoixeia_full"] = test["Ton"] + " " + test["Surname"] + " " + test["Name"] + ", κάτοικο "+ test["City"] + ", οδός " + test["Address"] + " αρ. " + test["Number"] + ", ΤΚ " + test["TK"] + ", με ΑΦΜ " + test["ΑΦΜ"] + "."
test["stoixeia"]=  test["Ton"] + " " + test["Surname"] + " " + test["Name"] 
filename = file[60:80]
test.to_excel(f"{filename}.xlsx", index = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\pallist\github\Project-Clean-Stoixeia-Ofeileti-Python\stoixeia ofeileti 2_11_22.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pallist/github/Project-Clean-Stoixeia-Ofeileti-Python/stoixeia%20ofeileti%202_11_22.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> names()
#       <a href='vscode-notebook-cell:/c%3A/Users/pallist/github/Project-Clean-Stoixeia-Ofeileti-Python/stoixeia%20ofeileti%202_11_22.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> if len(stoixeia.columns) > 4 :
#       <a href='vscode-notebook-cell:/c%3A/Users/pallist/github/Project-Clean-Stoixeia-Ofeileti-Python/stoixeia%20ofeileti%202_11_22.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>     cities()
#
# c:\Users\pallist\github\Project-Clean-Stoixeia-Ofeileti-Python\stoixeia ofeileti 2_11_22.ipynb Cell 10 in names()
#      <a href='vscode-notebook-cell:/c%3A/Users/pallist/github/Project-Clean-Stoixeia-Ofeileti-Python/stoixeia%20ofeileti%202_11_22.ipynb#X12sZmlsZQ%3D%3D?line=26'>27</a> name_list = []
#      <a href='vscode-notebook-cell:/c%3A/Users/pallist/github/Project-Clean-Stoixeia-Ofeileti-Python/stoixeia%20ofeileti%202_11_22.ipynb#X12sZmlsZQ%3D%3D?line=28'>29</a> for t in test["Name"] :
# ---> <a href='vscode-notebook-cell:/c%3A/Users/pallist/github/Project-Clean-Stoixeia-Ofeileti-Python/stoixeia%20ofeileti%202_11_22.ipynb#X12sZmlsZQ%3D%3D?line=29'>30</a>     if t[-1] == "Σ" :
#      <a href='vscode-notebook-cell:/c%3A/Users/pallist/github/Project-Clean-Stoixeia-Ofeileti-Python/stoixeia%20ofeileti%202_11_22.ipynb#X12sZmlsZQ%3D%3D?line=30'>31</a>         t = t[:-1]
#      <a href='vscode-notebook-cell:/c%3A/Users/pallist/github/Project-Clean-Stoixeia-Ofeileti-Python/stoixeia%20ofeileti%202_11_22.ipynb#X12sZmlsZQ%3D%3D?line=31'>32</a>     name_list.append(t)
#
# TypeError: 'float' object is not subscriptable

# %%
test
# Out:
#      Ton       Surname       Name          Father     City       Address  \
# 0    Την     ΣΑΡΑΝΤΑΡΗ  ΠΑΝΑΓΙΩΤΑ        ΠΑΝΤΕΛΗΣ     ΑΡΤΑ     ΧΑΛΚΙΑΔΕΣ
# 1    Την      ΜΠΑΣΟΥΚΟ     ΙΩΑΝΝΗ          ΛΟΥΚΑΣ  ΧΑΛΚΙΔΑ         ΧΑΙΝΑ
# 2    Την  ΧΡΥΣΤΟΠΟΥΛΟΥ    ΔΗΜΗΤΡΑ    ΚΩΝΣΤΑΝΤΙΝΟΣ    ΛΑΜΙΑ   ΠΑΛΑΙΟΛΟΓΟΥ
# 3    Την     ΚΟΛΟΤΟΥΡΟ     ΑΝΔΡΕΑ        ΓΕΩΡΓΙΟΣ  ΑΙΓΑΛΕΩ         ΣΑΜΟΥ
# 4    Την  ΓΕΩΡΓΟΥΛΑΚΟΥ  ΠΑΝΑΓΙΩΤΑ         ΙΩΑΝΝΗΣ   ΝΙΚΑΙΑ   ΚΑΛΛΙΠΟΛΕΩΣ
# ..   ...           ...        ...             ...      ...           ...
# 409  Την          ΦΑΚΑ       ΖΗΣΗ        ΑΧΙΛΛΕΑΣ   ΛΑΡΙΣΑ  ΠΡΟΦΗΤΗ ΗΛΙΑ
# 410  Την        RALUCA     MIRELA           MIHAI    ΑΘΗΝΑ       ΣΚΙΑΘΟΥ
# 411  Την     ΒΑΒΑΡΟΥΤΑ  ΠΑΝΑΓΙΩΤΗ         ΑΝΔΡΕΑΣ    ΠΑΤΡΑ      ΚΟΡΙΝΘΟΥ
# 412  Την       ΚΟΤΣΙΦΑ  ΠΑΝΑΓΙΩΤΗ          ΦΩΤΙΟΣ    ΑΘΗΝΑ     ΑΝΤΙΦΙΛΟΥ
# 413  Την     ELSHENIKY    ELTABEI  HASAN MOHAMMED    ΑΘΗΝΑ        ΠΟΝΤΟΥ
#
#     Number     TK        ΑΦΜ stoixeia
# 0      nan  47100  115068290
# 1        1  34100   26702675
# 2       14  35100  149853000
# 3       62  12243  165327791
# 4       18  18454  103197323
# ..     ...    ...        ...      ...
# 409     12  41335  104611180
# 410      8  11254  175667062
# 411    385  26222   46005178
# 412     19  11528   26875931
# 413     70  11527  127556214
#
# [414 rows x 10 columns]
